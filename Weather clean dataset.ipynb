# %% [markdown]
# # Inserting Libraries

# %%
import numpy as np
import pandas as pd
from datetime import datetime

# %%
df = pd.read_csv("weather_dataset_stage1.xls - Sheet 1 - weather_dataset (2).csv")

# %%
df.head(30)
# Out:
#                         weather_dataset    Unnamed: 1            Unnamed: 2  \
# 0                            tableName            NaN                   NaN
# 1                                   NaN           NaN                   NaN
# 2                     Date\tVARCHAR(512           NaN                   NaN
# 3                   temperature\tDOUBLE           NaN                   NaN
# 4           Average humidity (%\tDOUBLE           NaN                   NaN
# 5          Average dewpoint (°F\tDOUBLE           NaN                   NaN
# 6         Average barometer (in\tDOUBLE           NaN                   NaN
# 7        Average windspeed (mph\tDOUBLE           NaN                   NaN
# 8        Average gustspeed (mph\tDOUBLE           NaN                   NaN
# 9       Average direction (°deg\tDOUBLE           NaN                   NaN
# 10       Rainfall for month (in\tDOUBLE           NaN                   NaN
# 11        Rainfall for year (in\tDOUBLE           NaN                   NaN
# 12      Maximum rain per minute\tDOUBLE           NaN                   NaN
# 13      Maximum temperature (°F\tDOUBLE           NaN                   NaN
# 14      Minimum temperature (°F\tDOUBLE           NaN                   NaN
# 15          Maximum humidity (%\tDOUBLE           NaN                   NaN
# 16          Minimum humidity (%\tDOUBLE           NaN                   NaN
# 17             Maximum pressure\tDOUBLE           NaN                   NaN
# 18             Minimum pressure\tDOUBLE           NaN                   NaN
# 19       Maximum windspeed (mph\tDOUBLE           NaN                   NaN
# 20      Maximum gust speed (mph\tDOUBLE           NaN                   NaN
# 21       Maximum heat index (°F\tDOUBLE           NaN                   NaN
# 22                   Date1\tVARCHAR(512           NaN                   NaN
# 23                           Month\tINT           NaN                   NaN
# 24                diff_pressure\tDOUBLE           NaN                   NaN
# 25                                  NaN           NaN                   NaN
# 26                                  NaN           NaN                   NaN
# 27                                 Date   Temperature   Average humidity (%
# 28                           2022-01-01        '37.8'                '35.0'
# 29                          2022-01-02'        '43.2'                '32.0'
#
#                Unnamed: 3              Unnamed: 4               Unnamed: 5  \
# 0                     NaN                     NaN                      NaN
# 1                     NaN                     NaN                      NaN
# 2                     NaN                     NaN                      NaN
# 3                     NaN                     NaN                      NaN
# 4                     NaN                     NaN                      NaN
# 5                     NaN                     NaN                      NaN
# 6                     NaN                     NaN                      NaN
# 7                     NaN                     NaN                      NaN
# 8                     NaN                     NaN                      NaN
# 9                     NaN                     NaN                      NaN
# 10                    NaN                     NaN                      NaN
# 11                    NaN                     NaN                      NaN
# 12                    NaN                     NaN                      NaN
# 13                    NaN                     NaN                      NaN
# 14                    NaN                     NaN                      NaN
# 15                    NaN                     NaN                      NaN
# 16                    NaN                     NaN                      NaN
# 17                    NaN                     NaN                      NaN
# 18                    NaN                     NaN                      NaN
# 19                    NaN                     NaN                      NaN
# 20                    NaN                     NaN                      NaN
# 21                    NaN                     NaN                      NaN
# 22                    NaN                     NaN                      NaN
# 23                    NaN                     NaN                      NaN
# 24                    NaN                     NaN                      NaN
# 25                    NaN                     NaN                      NaN
# 26                    NaN                     NaN                      NaN
# 27   Average dewpoint (°F   Average barometer (in   Average windspeed (mph
# 28                 '12.7'                  '29.7'                   '26.4'
# 29                 '14.7'                  '29.5'                   '12.8'
#
#                  Unnamed: 6                Unnamed: 7  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
# 5                       NaN                       NaN
# 6                       NaN                       NaN
# 7                       NaN                       NaN
# 8                       NaN                       NaN
# 9                       NaN                       NaN
# 10                      NaN                       NaN
# 11                      NaN                       NaN
# 12                      NaN                       NaN
# 13                      NaN                       NaN
# 14                      NaN                       NaN
# 15                      NaN                       NaN
# 16                      NaN                       NaN
# 17                      NaN                       NaN
# 18                      NaN                       NaN
# 19                      NaN                       NaN
# 20                      NaN                       NaN
# 21                      NaN                       NaN
# 22                      NaN                       NaN
# 23                      NaN                       NaN
# 24                      NaN                       NaN
# 25                      NaN                       NaN
# 26                      NaN                       NaN
# 27   Average gustspeed (mph   Average direction (°deg
# 28                   '36.8'                   '274.0'
# 29                   '18.0'                   '240.0'
#
#                  Unnamed: 8             Unnamed: 9  ...           Unnamed: 13  \
# 0                       NaN                    NaN  ...                   NaN
# 1                       NaN                    NaN  ...                   NaN
# 2                       NaN                    NaN  ...                   NaN
# 3                       NaN                    NaN  ...                   NaN
# 4                       NaN                    NaN  ...                   NaN
# 5                       NaN                    NaN  ...                   NaN
# 6                       NaN                    NaN  ...                   NaN
# 7                       NaN                    NaN  ...                   NaN
# 8                       NaN                    NaN  ...                   NaN
# 9                       NaN                    NaN  ...                   NaN
# 10                      NaN                    NaN  ...                   NaN
# 11                      NaN                    NaN  ...                   NaN
# 12                      NaN                    NaN  ...                   NaN
# 13                      NaN                    NaN  ...                   NaN
# 14                      NaN                    NaN  ...                   NaN
# 15                      NaN                    NaN  ...                   NaN
# 16                      NaN                    NaN  ...                   NaN
# 17                      NaN                    NaN  ...                   NaN
# 18                      NaN                    NaN  ...                   NaN
# 19                      NaN                    NaN  ...                   NaN
# 20                      NaN                    NaN  ...                   NaN
# 21                      NaN                    NaN  ...                   NaN
# 22                      NaN                    NaN  ...                   NaN
# 23                      NaN                    NaN  ...                   NaN
# 24                      NaN                    NaN  ...                   NaN
# 25                      NaN                    NaN  ...                   NaN
# 26                      NaN                    NaN  ...                   NaN
# 27   Rainfall for month (in  Rainfall for year (in  ...   Maximum humidity (%
# 28                    '0.0'                  '0.0'  ...                 '4.0'
# 29                    '0.0'                  '0.0'  ...                 '4.0'
#
#              Unnamed: 14        Unnamed: 15        Unnamed: 16  \
# 0                    NaN                NaN                NaN
# 1                    NaN                NaN                NaN
# 2                    NaN                NaN                NaN
# 3                    NaN                NaN                NaN
# 4                    NaN                NaN                NaN
# 5                    NaN                NaN                NaN
# 6                    NaN                NaN                NaN
# 7                    NaN                NaN                NaN
# 8                    NaN                NaN                NaN
# 9                    NaN                NaN                NaN
# 10                   NaN                NaN                NaN
# 11                   NaN                NaN                NaN
# 12                   NaN                NaN                NaN
# 13                   NaN                NaN                NaN
# 14                   NaN                NaN                NaN
# 15                   NaN                NaN                NaN
# 16                   NaN                NaN                NaN
# 17                   NaN                NaN                NaN
# 18                   NaN                NaN                NaN
# 19                   NaN                NaN                NaN
# 20                   NaN                NaN                NaN
# 21                   NaN                NaN                NaN
# 22                   NaN                NaN                NaN
# 23                   NaN                NaN                NaN
# 24                   NaN                NaN                NaN
# 25                   NaN                NaN                NaN
# 26                   NaN                NaN                NaN
# 27   Minimum humidity (%   Maximum pressure   Minimum pressure
# 28                '27.0'           '29.762'           '29.596'
# 29                '16.0'           '29.669'           '29.268'
#
#                 Unnamed: 17               Unnamed: 18  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
# 5                       NaN                       NaN
# 6                       NaN                       NaN
# 7                       NaN                       NaN
# 8                       NaN                       NaN
# 9                       NaN                       NaN
# 10                      NaN                       NaN
# 11                      NaN                       NaN
# 12                      NaN                       NaN
# 13                      NaN                       NaN
# 14                      NaN                       NaN
# 15                      NaN                       NaN
# 16                      NaN                       NaN
# 17                      NaN                       NaN
# 18                      NaN                       NaN
# 19                      NaN                       NaN
# 20                      NaN                       NaN
# 21                      NaN                       NaN
# 22                      NaN                       NaN
# 23                      NaN                       NaN
# 24                      NaN                       NaN
# 25                      NaN                       NaN
# 26                      NaN                       NaN
# 27   Maximum windspeed (mph   Maximum gust speed (mph
# 28                   '41.4'                    '59.0'
# 29                   '35.7'                    '51.0'
#
#                 Unnamed: 19   Unnamed: 20 Unnamed: 21            Unnamed: 22
# 0                       NaN           NaN         NaN                    NaN
# 1                       NaN           NaN         NaN                    NaN
# 2                       NaN           NaN         NaN                    NaN
# 3                       NaN           NaN         NaN                    NaN
# 4                       NaN           NaN         NaN                    NaN
# 5                       NaN           NaN         NaN                    NaN
# 6                       NaN           NaN         NaN                    NaN
# 7                       NaN           NaN         NaN                    NaN
# 8                       NaN           NaN         NaN                    NaN
# 9                       NaN           NaN         NaN                    NaN
# 10                      NaN           NaN         NaN                    NaN
# 11                      NaN           NaN         NaN                    NaN
# 12                      NaN           NaN         NaN                    NaN
# 13                      NaN           NaN         NaN                    NaN
# 14                      NaN           NaN         NaN                    NaN
# 15                      NaN           NaN         NaN                    NaN
# 16                      NaN           NaN         NaN                    NaN
# 17                      NaN           NaN         NaN                    NaN
# 18                      NaN           NaN         NaN                    NaN
# 19                      NaN           NaN         NaN                    NaN
# 20                      NaN           NaN         NaN                    NaN
# 21                      NaN           NaN         NaN                    NaN
# 22                      NaN           NaN         NaN                    NaN
# 23                      NaN           NaN         NaN                    NaN
# 24                      NaN           NaN         NaN                    NaN
# 25                      NaN           NaN         NaN                    NaN
# 26                      NaN           NaN         NaN                    NaN
# 27   Maximum heat index (°F         Date1       Month          diff_pressure
# 28                   '40.0'  '2022-01-01'        '01'  '0.16600000000000037'
# 29                   '52.0'  '2022-01-02'        '01'   '0.4009999999999998'
#
# [30 rows x 23 columns]

# %% [markdown]
# # Dropping Null Values

# %%
df.dropna(inplace=True)
df.head()
# Out:
#    weather_dataset    Unnamed: 1            Unnamed: 2             Unnamed: 3  \
# 27            Date   Temperature   Average humidity (%   Average dewpoint (°F
# 28      2022-01-01        '37.8'                '35.0'                 '12.7'
# 29     2022-01-02'        '43.2'                '32.0'                 '14.7'
# 30     2022-01-03'        '25.7'                '60.0'                 '12.7'
# 31     2022-01-04'         '9.3'                '67.0'                  '0.1'
#
#                 Unnamed: 4               Unnamed: 5               Unnamed: 6  \
# 27   Average barometer (in   Average windspeed (mph   Average gustspeed (mph
# 28                  '29.7'                   '26.4'                   '36.8'
# 29                  '29.5'                   '12.8'                   '18.0'
# 30                  '29.7'                    '8.3'                   '12.2'
# 31                  '30.4'                    '2.9'                    '4.5'
#
#                   Unnamed: 7               Unnamed: 8             Unnamed: 9  \
# 27   Average direction (°deg   Rainfall for month (in  Rainfall for year (in
# 28                   '274.0'                    '0.0'                  '0.0'
# 29                   '240.0'                    '0.0'                  '0.0'
# 30                   '290.0'                    '0.0'                  '0.0'
# 31                    '47.0'                    '0.0'                  '0.0'
#
#     ...           Unnamed: 13           Unnamed: 14        Unnamed: 15  \
# 27  ...   Maximum humidity (%   Minimum humidity (%   Maximum pressure
# 28  ...                 '4.0'                '27.0'           '29.762'
# 29  ...                 '4.0'                '16.0'           '29.669'
# 30  ...                 '8.0'                '35.0'           '30.232'
# 31  ...                 '7.0'                '35.0'           '30.566'
#
#           Unnamed: 16              Unnamed: 17               Unnamed: 18  \
# 27   Minimum pressure   Maximum windspeed (mph   Maximum gust speed (mph
# 28           '29.596'                   '41.4'                    '59.0'
# 29           '29.268'                   '35.7'                    '51.0'
# 30            '29.26'                   '25.3'                    '38.0'
# 31           '30.227'                   '12.7'                    '20.0'
#
#                 Unnamed: 19   Unnamed: 20 Unnamed: 21            Unnamed: 22
# 27   Maximum heat index (°F         Date1       Month          diff_pressure
# 28                   '40.0'  '2022-01-01'        '01'  '0.16600000000000037'
# 29                   '52.0'  '2022-01-02'        '01'   '0.4009999999999998'
# 30                   '41.0'  '2022-01-03'        '01'   '0.9719999999999978'
# 31                   '32.0'  '2022-01-04'        '01'  '0.33899999999999864'
#
# [5 rows x 23 columns]

# %% [markdown]
# # Renaming All Collumns

# %%
df.rename( columns={'weather_dataset':'Date',
                    'Unnamed: 1':'Temperature','Unnamed: 2':'Average_humidity',
                    'Unnamed: 3':'Average_dewpoint','Unnamed: 4':'Average_barometer',
                    'Unnamed: 5':'Average_windspeed','Unnamed: 6':'Average_gustspeed',
                    'Unnamed: 7':'Average_direction','Unnamed: 8':'Rainfall_for_month',
                    'Unnamed: 9':'Rainfall_for_year','Unnamed: 10':'Maximum_rain_per_minute',
                    'Unnamed: 11':'Maximum_temperature','Unnamed: 12':'Minimum_temperature',
                    'Unnamed: 13':'Maximum_humidity','Unnamed: 14':'Minimum_humidity',
                    'Unnamed: 15':'Maximum_pressure','Unnamed: 16':'Minimum_pressure',
                    'Unnamed: 17':'Maximum_windspeed','Unnamed: 18':'Maximum_gust_speed',
                    'Unnamed: 19':'Maximum_heat_index','Unnamed: 20':'Date1',
                    'Unnamed: 21':'Month','Unnamed: 22':'diff_pressure'}, inplace=True )

# %%
df.head()
# Out:
#            Date   Temperature      Average_humidity       Average_dewpoint  \
# 27         Date   Temperature   Average humidity (%   Average dewpoint (°F
# 28   2022-01-01        '37.8'                '35.0'                 '12.7'
# 29  2022-01-02'        '43.2'                '32.0'                 '14.7'
# 30  2022-01-03'        '25.7'                '60.0'                 '12.7'
# 31  2022-01-04'         '9.3'                '67.0'                  '0.1'
#
#          Average_barometer        Average_windspeed        Average_gustspeed  \
# 27   Average barometer (in   Average windspeed (mph   Average gustspeed (mph
# 28                  '29.7'                   '26.4'                   '36.8'
# 29                  '29.5'                   '12.8'                   '18.0'
# 30                  '29.7'                    '8.3'                   '12.2'
# 31                  '30.4'                    '2.9'                    '4.5'
#
#            Average_direction       Rainfall_for_month      Rainfall_for_year  \
# 27   Average direction (°deg   Rainfall for month (in  Rainfall for year (in
# 28                   '274.0'                    '0.0'                  '0.0'
# 29                   '240.0'                    '0.0'                  '0.0'
# 30                   '290.0'                    '0.0'                  '0.0'
# 31                    '47.0'                    '0.0'                  '0.0'
#
#     ...      Maximum_humidity      Minimum_humidity   Maximum_pressure  \
# 27  ...   Maximum humidity (%   Minimum humidity (%   Maximum pressure
# 28  ...                 '4.0'                '27.0'           '29.762'
# 29  ...                 '4.0'                '16.0'           '29.669'
# 30  ...                 '8.0'                '35.0'           '30.232'
# 31  ...                 '7.0'                '35.0'           '30.566'
#
#      Minimum_pressure        Maximum_windspeed        Maximum_gust_speed  \
# 27   Minimum pressure   Maximum windspeed (mph   Maximum gust speed (mph
# 28           '29.596'                   '41.4'                    '59.0'
# 29           '29.268'                   '35.7'                    '51.0'
# 30            '29.26'                   '25.3'                    '38.0'
# 31           '30.227'                   '12.7'                    '20.0'
#
#          Maximum_heat_index         Date1   Month          diff_pressure
# 27   Maximum heat index (°F         Date1   Month          diff_pressure
# 28                   '40.0'  '2022-01-01'    '01'  '0.16600000000000037'
# 29                   '52.0'  '2022-01-02'    '01'   '0.4009999999999998'
# 30                   '41.0'  '2022-01-03'    '01'   '0.9719999999999978'
# 31                   '32.0'  '2022-01-04'    '01'  '0.33899999999999864'
#
# [5 rows x 23 columns]

# %%
df.drop(index=27,axis=0)
# Out:
#              Date Temperature Average_humidity Average_dewpoint  \
# 28     2022-01-01      '37.8'           '35.0'           '12.7'
# 29    2022-01-02'      '43.2'           '32.0'           '14.7'
# 30    2022-01-03'      '25.7'           '60.0'           '12.7'
# 31    2022-01-04'       '9.3'           '67.0'            '0.1'
# 32    2022-01-05'      '23.5'           '30.0'           '-5.3'
# ...           ...         ...              ...              ...
# 3926  2022-07-25'      '62.8'           '60.0'           '48.1'
# 3927  2022-07-26'      '60.6'           '68.0'           '48.9'
# 3928  2022-07-27'      '61.7'           '64.0'           '47.4'
# 3929  2022-07-28'      '60.5'           '61.0'           '45.3'
# 3930  2022-07-28'      '60.5'           '61.0'           '45.3'
#
#      Average_barometer Average_windspeed Average_gustspeed Average_direction  \
# 28              '29.7'            '26.4'            '36.8'           '274.0'
# 29              '29.5'            '12.8'            '18.0'           '240.0'
# 30              '29.7'             '8.3'            '12.2'           '290.0'
# 31              '30.4'             '2.9'             '4.5'            '47.0'
# 32              '29.9'            '16.7'            '23.1'           '265.0'
# ...                ...               ...               ...               ...
# 3926            '29.7'             '2.5'             '4.0'           '242.0'
# 3927            '29.8'             '1.7'             '2.9'           '357.0'
# 3928            '29.9'             '2.2'             '4.0'            '66.0'
# 3929            '29.7'             '4.0'             '6.2'           '248.0'
# 3930            '29.7'             '4.0'             '6.2'           '248.0'
#
#      Rainfall_for_month Rainfall_for_year  ... Maximum_humidity  \
# 28                '0.0'             '0.0'  ...            '4.0'
# 29                '0.0'             '0.0'  ...            '4.0'
# 30                '0.0'             '0.0'  ...            '8.0'
# 31                '0.0'             '0.0'  ...            '7.0'
# 32                '0.0'             '0.0'  ...            '5.0'
# ...                 ...               ...  ...              ...
# 3926             '0.33'            '4.47'  ...           '90.0'
# 3927             '0.33'            '4.47'  ...           '90.0'
# 3928             '0.33'            '4.47'  ...           '96.0'
# 3929             '0.35'            '4.49'  ...           '94.0'
# 3930             '0.35'            '4.49'  ...           '94.0'
#
#      Minimum_humidity Maximum_pressure Minimum_pressure Maximum_windspeed  \
# 28             '27.0'         '29.762'         '29.596'            '41.4'
# 29             '16.0'         '29.669'         '29.268'            '35.7'
# 30             '35.0'         '30.232'          '29.26'            '25.3'
# 31             '35.0'         '30.566'         '30.227'            '12.7'
# 32             '13.0'         '30.233'         '29.568'            '38.0'
# ...               ...              ...              ...               ...
# 3926           '36.0'         '29.781'         '29.645'             '8.1'
# 3927           '40.0'          '29.93'         '29.745'            '11.5'
# 3928           '35.0'         '29.941'         '29.781'            '13.8'
# 3929           '35.0'         '29.792'         '29.675'            '17.3'
# 3930           '35.0'         '29.792'         '29.675'            '17.3'
#
#      Maximum_gust_speed Maximum_heat_index         Date1 Month  \
# 28               '59.0'             '40.0'  '2022-01-01'  '01'
# 29               '51.0'             '52.0'  '2022-01-02'  '01'
# 30               '38.0'             '41.0'  '2022-01-03'  '01'
# 31               '20.0'             '32.0'  '2022-01-04'  '01'
# 32               '53.0'             '32.0'  '2022-01-05'  '01'
# ...                 ...                ...           ...   ...
# 3926             '17.3'             '77.5'  '2022-07-25'  '07'
# 3927             '15.0'             '77.5'  '2022-07-26'  '07'
# 3928             '18.4'             '78.2'  '2022-07-27'  '07'
# 3929             '26.5'             '77.6'  '2022-07-28'  '07'
# 3930             '26.5'             '77.6'  '2022-07-28'  '07'
#
#                diff_pressure
# 28     '0.16600000000000037'
# 29      '0.4009999999999998'
# 30      '0.9719999999999978'
# 31     '0.33899999999999864'
# 32      '0.6649999999999991'
# ...                      ...
# 3926   '0.13599999999999923'
# 3927   '0.18499999999999872'
# 3928   '0.16000000000000014'
# 3929  '0.11700000000000088';
# 3930  '0.11700000000000088';
#
# [3903 rows x 23 columns]

# %% [markdown]
# # Resetting Index To 0

# %%
df.reset_index(drop=True,inplace=True)
df.head()
# Out:
#           Date   Temperature      Average_humidity       Average_dewpoint  \
# 0         Date   Temperature   Average humidity (%   Average dewpoint (°F
# 1   2022-01-01        '37.8'                '35.0'                 '12.7'
# 2  2022-01-02'        '43.2'                '32.0'                 '14.7'
# 3  2022-01-03'        '25.7'                '60.0'                 '12.7'
# 4  2022-01-04'         '9.3'                '67.0'                  '0.1'
#
#         Average_barometer        Average_windspeed        Average_gustspeed  \
# 0   Average barometer (in   Average windspeed (mph   Average gustspeed (mph
# 1                  '29.7'                   '26.4'                   '36.8'
# 2                  '29.5'                   '12.8'                   '18.0'
# 3                  '29.7'                    '8.3'                   '12.2'
# 4                  '30.4'                    '2.9'                    '4.5'
#
#           Average_direction       Rainfall_for_month      Rainfall_for_year  \
# 0   Average direction (°deg   Rainfall for month (in  Rainfall for year (in
# 1                   '274.0'                    '0.0'                  '0.0'
# 2                   '240.0'                    '0.0'                  '0.0'
# 3                   '290.0'                    '0.0'                  '0.0'
# 4                    '47.0'                    '0.0'                  '0.0'
#
#    ...      Maximum_humidity      Minimum_humidity   Maximum_pressure  \
# 0  ...   Maximum humidity (%   Minimum humidity (%   Maximum pressure
# 1  ...                 '4.0'                '27.0'           '29.762'
# 2  ...                 '4.0'                '16.0'           '29.669'
# 3  ...                 '8.0'                '35.0'           '30.232'
# 4  ...                 '7.0'                '35.0'           '30.566'
#
#     Minimum_pressure        Maximum_windspeed        Maximum_gust_speed  \
# 0   Minimum pressure   Maximum windspeed (mph   Maximum gust speed (mph
# 1           '29.596'                   '41.4'                    '59.0'
# 2           '29.268'                   '35.7'                    '51.0'
# 3            '29.26'                   '25.3'                    '38.0'
# 4           '30.227'                   '12.7'                    '20.0'
#
#         Maximum_heat_index         Date1   Month          diff_pressure
# 0   Maximum heat index (°F         Date1   Month          diff_pressure
# 1                   '40.0'  '2022-01-01'    '01'  '0.16600000000000037'
# 2                   '52.0'  '2022-01-02'    '01'   '0.4009999999999998'
# 3                   '41.0'  '2022-01-03'    '01'   '0.9719999999999978'
# 4                   '32.0'  '2022-01-04'    '01'  '0.33899999999999864'
#
# [5 rows x 23 columns]

# %% [markdown]
# # Removing Apostrophe from all the data points

# %%
df.drop(0,inplace=True)

# %%
df['Date'] = df['Date'].str.replace(r"'","")
df['Temperature'] = df['Temperature'].str.replace(r"'","")
df['Average_humidity'] = df['Average_humidity'].str.replace(r"'","")
df['Average_dewpoint'] = df['Average_dewpoint'].str.replace(r"'","")
df['Average_barometer'] = df['Average_barometer'].str.replace(r"'","")
df['Average_windspeed'] = df['Average_windspeed'].str.replace(r"'","")
df['Average_gustspeed'] = df['Average_gustspeed'].str.replace(r"'","")
df['Average_direction'] = df['Average_direction'].str.replace(r"'","")
df['Rainfall_for_month'] = df['Rainfall_for_month'].str.replace(r"'","")
df['Rainfall_for_year'] = df['Rainfall_for_year'].str.replace(r"'","")
df['Maximum_rain_per_minute'] = df['Maximum_rain_per_minute'].str.replace(r"'","")
df['Maximum_temperature'] = df['Maximum_temperature'].str.replace(r"'","")
df['Minimum_temperature'] = df['Minimum_temperature'].str.replace(r"'","")
df['Maximum_humidity'] = df['Maximum_humidity'].str.replace(r"'","")
df['Minimum_humidity'] = df['Minimum_humidity'].str.replace(r"'","")
df['Maximum_pressure'] = df['Maximum_pressure'].str.replace(r"'","")
df['Minimum_pressure'] = df['Minimum_pressure'].str.replace(r"'","")
df['Maximum_windspeed'] = df['Maximum_windspeed'].str.replace(r"'","")
df['Maximum_gust_speed'] = df['Maximum_gust_speed'].str.replace(r"'","")
df['Maximum_heat_index'] = df['Maximum_heat_index'].str.replace(r"'","")
df['Date1'] = df['Date1'].str.replace(r"'","")
df['Month'] = df['Month'].str.replace(r"'","")
df['diff_pressure'] = df['diff_pressure'].str.replace(r"'","")
df.head()
# Out:
#          Date Temperature Average_humidity Average_dewpoint Average_barometer  \
# 1  2022-01-01        37.8             35.0             12.7              29.7
# 2  2022-01-02        43.2             32.0             14.7              29.5
# 3  2022-01-03        25.7             60.0             12.7              29.7
# 4  2022-01-04         9.3             67.0              0.1              30.4
# 5  2022-01-05        23.5             30.0             -5.3              29.9
#
#   Average_windspeed Average_gustspeed Average_direction Rainfall_for_month  \
# 1              26.4              36.8             274.0                0.0
# 2              12.8              18.0             240.0                0.0
# 3               8.3              12.2             290.0                0.0
# 4               2.9               4.5              47.0                0.0
# 5              16.7              23.1             265.0                0.0
#
#   Rainfall_for_year  ... Maximum_humidity Minimum_humidity Maximum_pressure  \
# 1               0.0  ...              4.0             27.0           29.762
# 2               0.0  ...              4.0             16.0           29.669
# 3               0.0  ...              8.0             35.0           30.232
# 4               0.0  ...              7.0             35.0           30.566
# 5               0.0  ...              5.0             13.0           30.233
#
#   Minimum_pressure Maximum_windspeed Maximum_gust_speed Maximum_heat_index  \
# 1           29.596              41.4               59.0               40.0
# 2           29.268              35.7               51.0               52.0
# 3            29.26              25.3               38.0               41.0
# 4           30.227              12.7               20.0               32.0
# 5           29.568              38.0               53.0               32.0
#
#         Date1 Month        diff_pressure
# 1  2022-01-01    01  0.16600000000000037
# 2  2022-01-02    01   0.4009999999999998
# 3  2022-01-03    01   0.9719999999999978
# 4  2022-01-04    01  0.33899999999999864
# 5  2022-01-05    01   0.6649999999999991
#
# [5 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['Date', 'Temperature', 'Average_humidity', 'Average_dewpoint',
#        'Average_barometer', 'Average_windspeed', 'Average_gustspeed',
#        'Average_direction', 'Rainfall_for_month', 'Rainfall_for_year',
#        'Maximum_rain_per_minute', 'Maximum_temperature', 'Minimum_temperature',
#        'Maximum_humidity', 'Minimum_humidity', 'Maximum_pressure',
#        'Minimum_pressure', 'Maximum_windspeed', 'Maximum_gust_speed',
#        'Maximum_heat_index', 'Date1', 'Month', 'diff_pressure'],
#       dtype='object')

# %% [markdown]
# # Changing Data Type Of All Columns

# %%
df['Temperature'] = df['Temperature'].astype(float)
df['Average_humidity'] = df['Average_humidity'].astype(float)
df['Average_dewpoint'] = df['Average_dewpoint'].astype(float)
df['Average_barometer'] = df['Average_barometer'].astype(float)
df['Average_windspeed'] = df['Average_windspeed'].astype(float)
df['Average_gustspeed'] = df['Average_gustspeed'].astype(float)
df['Average_direction'] = df['Average_direction'].astype(float)
df['Rainfall_for_month'] = df['Rainfall_for_month'].astype(float)
df['Rainfall_for_year'] = df['Rainfall_for_year'].astype(float)
df['Maximum_rain_per_minute'] = df['Maximum_rain_per_minute'].astype(float)
df['Maximum_temperature'] = df['Maximum_temperature'].astype(float)
df['Minimum_temperature'] = df['Minimum_temperature'].astype(float)
df['Maximum_humidity'] = df['Maximum_humidity'].astype(float)
df['Minimum_humidity'] = df['Minimum_humidity'].astype(float)
df['Maximum_pressure'] = df['Maximum_pressure'].astype(float)
df['Minimum_pressure'] = df['Minimum_pressure'].astype(float)
df['Maximum_windspeed'] = df['Maximum_windspeed'].astype(float)
df['Maximum_gust_speed'] = df['Maximum_gust_speed'].astype(float)
df['Maximum_heat_index'] = df['Maximum_heat_index'].astype(float)
df['Month'] = df['Month'].astype(int)

# %%
df.drop(columns=['Date1'],axis=1,inplace=True)

# %% [markdown]
# # Removing ';' from data points

# %%
df['diff_pressure'] = df['diff_pressure'].str.replace(r";","")
df['diff_pressure'] = df['diff_pressure'].astype(float)

# %%
df.head()
# Out:
#          Date  Temperature  Average_humidity  Average_dewpoint  \
# 1  2022-01-01         37.8              35.0              12.7
# 2  2022-01-02         43.2              32.0              14.7
# 3  2022-01-03         25.7              60.0              12.7
# 4  2022-01-04          9.3              67.0               0.1
# 5  2022-01-05         23.5              30.0              -5.3
#
#    Average_barometer  Average_windspeed  Average_gustspeed  Average_direction  \
# 1               29.7               26.4               36.8              274.0
# 2               29.5               12.8               18.0              240.0
# 3               29.7                8.3               12.2              290.0
# 4               30.4                2.9                4.5               47.0
# 5               29.9               16.7               23.1              265.0
#
#    Rainfall_for_month  Rainfall_for_year  ...  Minimum_temperature  \
# 1                 0.0                0.0  ...                 34.0
# 2                 0.0                0.0  ...                 37.0
# 3                 0.0                0.0  ...                  6.0
# 4                 0.0                0.0  ...                 -0.0
# 5                 0.0                0.0  ...                 15.0
#
#    Maximum_humidity  Minimum_humidity  Maximum_pressure  Minimum_pressure  \
# 1               4.0              27.0            29.762            29.596
# 2               4.0              16.0            29.669            29.268
# 3               8.0              35.0            30.232            29.260
# 4               7.0              35.0            30.566            30.227
# 5               5.0              13.0            30.233            29.568
#
#    Maximum_windspeed  Maximum_gust_speed  Maximum_heat_index  Month  \
# 1               41.4                59.0                40.0      1
# 2               35.7                51.0                52.0      1
# 3               25.3                38.0                41.0      1
# 4               12.7                20.0                32.0      1
# 5               38.0                53.0                32.0      1
#
#    diff_pressure
# 1          0.166
# 2          0.401
# 3          0.972
# 4          0.339
# 5          0.665
#
# [5 rows x 22 columns]

# %% [markdown]
# # Dropping Duplicates

# %%
df.drop_duplicates()
# Out:
#             Date  Temperature  Average_humidity  Average_dewpoint  \
# 1     2022-01-01         37.8              35.0              12.7
# 2     2022-01-02         43.2              32.0              14.7
# 3     2022-01-03         25.7              60.0              12.7
# 4     2022-01-04          9.3              67.0               0.1
# 5     2022-01-05         23.5              30.0              -5.3
# ...          ...          ...               ...               ...
# 3898  2022-07-24         64.1              62.0              49.8
# 3899  2022-07-25         62.8              60.0              48.1
# 3900  2022-07-26         60.6              68.0              48.9
# 3901  2022-07-27         61.7              64.0              47.4
# 3902  2022-07-28         60.5              61.0              45.3
#
#       Average_barometer  Average_windspeed  Average_gustspeed  \
# 1                  29.7               26.4               36.8
# 2                  29.5               12.8               18.0
# 3                  29.7                8.3               12.2
# 4                  30.4                2.9                4.5
# 5                  29.9               16.7               23.1
# ...                 ...                ...                ...
# 3898               29.6                3.6                5.8
# 3899               29.7                2.5                4.0
# 3900               29.8                1.7                2.9
# 3901               29.9                2.2                4.0
# 3902               29.7                4.0                6.2
#
#       Average_direction  Rainfall_for_month  Rainfall_for_year  ...  \
# 1                 274.0                0.00               0.00  ...
# 2                 240.0                0.00               0.00  ...
# 3                 290.0                0.00               0.00  ...
# 4                  47.0                0.00               0.00  ...
# 5                 265.0                0.00               0.00  ...
# ...                 ...                 ...                ...  ...
# 3898              240.0                0.24               4.38  ...
# 3899              242.0                0.33               4.47  ...
# 3900              357.0                0.33               4.47  ...
# 3901               66.0                0.33               4.47  ...
# 3902              248.0                0.35               4.49  ...
#
#       Minimum_temperature  Maximum_humidity  Minimum_humidity  \
# 1                    34.0               4.0              27.0
# 2                    37.0               4.0              16.0
# 3                     6.0               8.0              35.0
# 4                    -0.0               7.0              35.0
# 5                    15.0               5.0              13.0
# ...                   ...               ...               ...
# 3898                 55.3              86.0              35.0
# 3899                 55.1              90.0              36.0
# 3900                 50.5              90.0              40.0
# 3901                 43.6              96.0              35.0
# 3902                 46.0              94.0              35.0
#
#       Maximum_pressure  Minimum_pressure  Maximum_windspeed  \
# 1               29.762            29.596               41.4
# 2               29.669            29.268               35.7
# 3               30.232            29.260               25.3
# 4               30.566            30.227               12.7
# 5               30.233            29.568               38.0
# ...                ...               ...                ...
# 3898            29.686            29.577               15.0
# 3899            29.781            29.645                8.1
# 3900            29.930            29.745               11.5
# 3901            29.941            29.781               13.8
# 3902            29.792            29.675               17.3
#
#       Maximum_gust_speed  Maximum_heat_index  Month  diff_pressure
# 1                   59.0                40.0      1          0.166
# 2                   51.0                52.0      1          0.401
# 3                   38.0                41.0      1          0.972
# 4                   20.0                32.0      1          0.339
# 5                   53.0                32.0      1          0.665
# ...                  ...                 ...    ...            ...
# 3898                25.3                77.4      7          0.109
# 3899                17.3                77.5      7          0.136
# 3900                15.0                77.5      7          0.185
# 3901                18.4                78.2      7          0.160
# 3902                26.5                77.6      7          0.117
#
# [3902 rows x 22 columns]

# %% [markdown]
# # Removing Invalid Date

# %%
indexAge = df[df['Date']=='2022-02-29'].index
df.drop(indexAge , inplace=True)
df.head(30)
# Out:
#           Date  Temperature  Average_humidity  Average_dewpoint  \
# 1   2022-01-01         37.8              35.0              12.7
# 2   2022-01-02         43.2              32.0              14.7
# 3   2022-01-03         25.7              60.0              12.7
# 4   2022-01-04          9.3              67.0               0.1
# 5   2022-01-05         23.5              30.0              -5.3
# 6   2022-01-06         24.8              42.0               4.6
# 7   2022-01-07         34.2              60.0              21.6
# 8   2022-01-08         42.1              41.0              20.0
# 9   2022-01-09         30.3              46.0              11.4
# 10  2022-01-10         26.2              38.0               3.6
# 11  2022-01-11         30.1              41.0               9.0
# 12  2022-01-12         23.4              60.0              11.0
# 13  2022-01-13         32.4              47.0              14.6
# 14  2022-01-14         33.1              45.0              14.2
# 15  2022-01-15         35.7              42.0              14.5
# 16  2022-01-16         41.6              28.0               9.7
# 17  2022-01-17         40.9              21.0               3.1
# 18  2022-01-18         43.4              15.0              -1.7
# 19  2022-01-19         46.6              19.0               3.6
# 20  2022-01-20         40.0              27.0              -1.0
# 21  2022-01-21         48.2              11.0              -4.6
# 22  2022-01-22         44.8              40.0              20.8
# 23  2022-01-23         24.8              81.0              19.6
# 24  2022-01-24         35.4              68.0              25.0
# 25  2022-01-25         21.0              77.0              14.5
# 26  2022-01-26          2.8              73.0              -4.0
# 27  2022-01-27          7.9              51.0              -8.1
# 28  2022-01-28         21.8              43.0               2.6
# 29  2022-01-29         22.5              40.0               1.3
# 30  2022-01-30         36.0              33.0               9.4
#
#     Average_barometer  Average_windspeed  Average_gustspeed  \
# 1                29.7               26.4               36.8
# 2                29.5               12.8               18.0
# 3                29.7                8.3               12.2
# 4                30.4                2.9                4.5
# 5                29.9               16.7               23.1
# 6                29.8               16.0               23.9
# 7                29.7               20.4               30.0
# 8                29.8               17.5               25.2
# 9                30.0                6.9               10.6
# 10               30.4               18.2               24.6
# 11               30.3               17.0               24.6
# 12               30.3                7.4               11.0
# 13               30.2               16.3               22.6
# 14               30.2                9.9               14.0
# 15               30.3                7.9               11.8
# 16               30.3               11.9               16.7
# 17               30.3                6.7                9.7
# 18               30.3                9.6               14.7
# 19               30.3                7.0               10.5
# 20               30.4                4.8                7.4
# 21               30.0               12.4               16.8
# 22               29.9               11.8               16.3
# 23               30.2                3.7                5.3
# 24               30.0                8.2               10.8
# 25               29.9                4.3                6.1
# 26               30.3                3.9                5.6
# 27               30.4               12.7               17.7
# 28               30.2               19.6               28.0
# 29               30.3                9.4               14.4
# 30               30.3               15.7               21.3
#
#     Average_direction  Rainfall_for_month  Rainfall_for_year  ...  \
# 1               274.0                0.00               0.00  ...
# 2               240.0                0.00               0.00  ...
# 3               290.0                0.00               0.00  ...
# 4                47.0                0.00               0.00  ...
# 5               265.0                0.00               0.00  ...
# 6               276.0                0.00               0.00  ...
# 7               276.0                0.00               0.00  ...
# 8               265.0                0.00               0.00  ...
# 9               292.0                0.00               0.00  ...
# 10              258.0                0.00               0.00  ...
# 11              270.0                0.00               0.00  ...
# 12              351.0                0.03               0.03  ...
# 13              254.0                0.03               0.03  ...
# 14              259.0                0.03               0.03  ...
# 15              270.0                0.03               0.03  ...
# 16              269.0                0.03               0.03  ...
# 17              276.0                0.03               0.03  ...
# 18              288.0                0.03               0.03  ...
# 19              293.0                0.03               0.03  ...
# 20              285.0                0.03               0.03  ...
# 21              257.0                0.03               0.03  ...
# 22              264.0                0.03               0.03  ...
# 23               52.0                0.03               0.03  ...
# 24              281.0                0.09               0.09  ...
# 25               35.0                0.20               0.20  ...
# 26               51.0                0.20               0.20  ...
# 27              263.0                0.20               0.20  ...
# 28              269.0                0.20               0.20  ...
# 29              267.0                0.20               0.20  ...
# 30              261.0                0.21               0.21  ...
#
#     Minimum_temperature  Maximum_humidity  Minimum_humidity  Maximum_pressure  \
# 1                  34.0               4.0              27.0            29.762
# 2                  37.0               4.0              16.0            29.669
# 3                   6.0               8.0              35.0            30.232
# 4                  -0.0               7.0              35.0            30.566
# 5                  15.0               5.0              13.0            30.233
# 6                  19.0               5.0              27.0            29.879
# 7                  27.0               8.0              46.0            29.860
# 8                  36.0               5.0              28.0            29.883
# 9                  19.0               8.0              27.0            30.446
# 10                 22.0               4.0              29.0            30.489
# 11                 26.0               5.0              29.0            30.421
# 12                 16.0               8.0              41.0            30.524
# 13                 28.0               5.0              34.0            30.340
# 14                 28.0               5.0              34.0            30.271
# 15                 27.0               5.0              28.0            30.405
# 16                 32.0               4.0              14.0            30.432
# 17                 28.0               2.0              11.0            30.435
# 18                 27.0               2.0               8.0            30.425
# 19                 36.0               3.0               7.0            30.333
# 20                 16.0               6.0               4.0            30.607
# 21                 41.0               1.0               6.0            30.143
# 22                 38.0               6.0              17.0            29.911
# 23                 12.0               8.0              63.0            30.473
# 24                 13.0               9.0              40.0            30.436
# 25                  5.0               9.0              45.0            30.138
# 26                 -3.0               7.0              65.0            30.535
# 27                -11.0               7.0              25.0            30.619
# 28                 15.0               5.0              31.0            30.250
# 29                 15.0               5.0              27.0            30.408
# 30                 27.0               4.0              22.0            30.435
#
#     Minimum_pressure  Maximum_windspeed  Maximum_gust_speed  \
# 1             29.596               41.4                59.0
# 2             29.268               35.7                51.0
# 3             29.260               25.3                38.0
# 4             30.227               12.7                20.0
# 5             29.568               38.0                53.0
# 6             29.637               29.9                48.0
# 7             29.602               38.0                54.0
# 8             29.627               35.7                49.0
# 9             29.575               24.2                36.0
# 10            30.291               31.1                46.0
# 11            30.112               31.1                44.0
# 12            30.012               25.3                33.0
# 13            30.046               32.2                47.0
# 14            30.115               29.9                32.0
# 15            30.201               19.6                26.0
# 16            30.127               26.5                37.0
# 17            30.093               21.9                26.0
# 18            30.190               24.2                36.0
# 19            30.154               20.7                28.0
# 20            30.016               18.4                26.0
# 21            29.871               25.3                35.0
# 22            29.784               31.1                44.0
# 23            29.855               12.7                16.0
# 24            29.689               26.5                35.0
# 25            29.652               23.0                26.0
# 26            29.879               15.0                20.0
# 27            30.131               34.5                47.0
# 28            30.063               43.7                58.0
# 29            30.240               28.8                47.0
# 30            30.102               32.2                44.0
#
#     Maximum_heat_index  Month  diff_pressure
# 1                 40.0      1          0.166
# 2                 52.0      1          0.401
# 3                 41.0      1          0.972
# 4                 32.0      1          0.339
# 5                 32.0      1          0.665
# 6                 32.0      1          0.242
# 7                 39.0      1          0.258
# 8                 51.0      1          0.256
# 9                 41.0      1          0.871
# 10                32.0      1          0.198
# 11                36.0      1          0.309
# 12                32.0      1          0.512
# 13                38.0      1          0.294
# 14                39.0      1          0.156
# 15                43.0      1          0.204
# 16                53.0      1          0.305
# 17                54.0      1          0.342
# 18                52.0      1          0.235
# 19                57.0      1          0.179
# 20                61.0      1          0.591
# 21                55.0      1          0.272
# 22                52.0      1          0.127
# 23                38.0      1          0.618
# 24                47.0      1          0.747
# 25                39.0      1          0.486
# 26                32.0      1          0.656
# 27                32.0      1          0.488
# 28                32.0      1          0.187
# 29                32.0      1          0.168
# 30                46.0      1          0.333
#
# [30 rows x 22 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#            Date  Temperature  Average_humidity  Average_dewpoint  \
# 1    2022-01-01         37.8              35.0              12.7
# 2    2022-01-02         43.2              32.0              14.7
# 3    2022-01-03         25.7              60.0              12.7
# 4    2022-01-04          9.3              67.0               0.1
# 5    2022-01-05         23.5              30.0              -5.3
# ...         ...          ...               ...               ...
# 3899 2022-07-25         62.8              60.0              48.1
# 3900 2022-07-26         60.6              68.0              48.9
# 3901 2022-07-27         61.7              64.0              47.4
# 3902 2022-07-28         60.5              61.0              45.3
# 3903 2022-07-28         60.5              61.0              45.3
#
#       Average_barometer  Average_windspeed  Average_gustspeed  \
# 1                  29.7               26.4               36.8
# 2                  29.5               12.8               18.0
# 3                  29.7                8.3               12.2
# 4                  30.4                2.9                4.5
# 5                  29.9               16.7               23.1
# ...                 ...                ...                ...
# 3899               29.7                2.5                4.0
# 3900               29.8                1.7                2.9
# 3901               29.9                2.2                4.0
# 3902               29.7                4.0                6.2
# 3903               29.7                4.0                6.2
#
#       Average_direction  Rainfall_for_month  Rainfall_for_year  ...  \
# 1                 274.0                0.00               0.00  ...
# 2                 240.0                0.00               0.00  ...
# 3                 290.0                0.00               0.00  ...
# 4                  47.0                0.00               0.00  ...
# 5                 265.0                0.00               0.00  ...
# ...                 ...                 ...                ...  ...
# 3899              242.0                0.33               4.47  ...
# 3900              357.0                0.33               4.47  ...
# 3901               66.0                0.33               4.47  ...
# 3902              248.0                0.35               4.49  ...
# 3903              248.0                0.35               4.49  ...
#
#       Minimum_temperature  Maximum_humidity  Minimum_humidity  \
# 1                    34.0               4.0              27.0
# 2                    37.0               4.0              16.0
# 3                     6.0               8.0              35.0
# 4                    -0.0               7.0              35.0
# 5                    15.0               5.0              13.0
# ...                   ...               ...               ...
# 3899                 55.1              90.0              36.0
# 3900                 50.5              90.0              40.0
# 3901                 43.6              96.0              35.0
# 3902                 46.0              94.0              35.0
# 3903                 46.0              94.0              35.0
#
#       Maximum_pressure  Minimum_pressure  Maximum_windspeed  \
# 1               29.762            29.596               41.4
# 2               29.669            29.268               35.7
# 3               30.232            29.260               25.3
# 4               30.566            30.227               12.7
# 5               30.233            29.568               38.0
# ...                ...               ...                ...
# 3899            29.781            29.645                8.1
# 3900            29.930            29.745               11.5
# 3901            29.941            29.781               13.8
# 3902            29.792            29.675               17.3
# 3903            29.792            29.675               17.3
#
#       Maximum_gust_speed  Maximum_heat_index  Month  diff_pressure
# 1                   59.0                40.0      1          0.166
# 2                   51.0                52.0      1          0.401
# 3                   38.0                41.0      1          0.972
# 4                   20.0                32.0      1          0.339
# 5                   53.0                32.0      1          0.665
# ...                  ...                 ...    ...            ...
# 3899                17.3                77.5      7          0.136
# 3900                15.0                77.5      7          0.185
# 3901                18.4                78.2      7          0.160
# 3902                26.5                77.6      7          0.117
# 3903                26.5                77.6      7          0.117
#
# [3901 rows x 22 columns]

# %% [markdown]
# # Making Year Corrections

# %%
from datetime import datetime, timedelta
df['year_offset'] = (df['Date'] == datetime(2022, 1, 1)).cumsum() - 1
df['Date'] = df.apply(lambda x: x['Date'].replace(year=x['Date'].year + x['year_offset']), axis=1)

# %%
df
# Out:
#            Date  Temperature  Average_humidity  Average_dewpoint  \
# 1    2022-01-01         37.8              35.0              12.7
# 2    2022-01-02         43.2              32.0              14.7
# 3    2022-01-03         25.7              60.0              12.7
# 4    2022-01-04          9.3              67.0               0.1
# 5    2022-01-05         23.5              30.0              -5.3
# ...         ...          ...               ...               ...
# 3899 2033-07-25         62.8              60.0              48.1
# 3900 2033-07-26         60.6              68.0              48.9
# 3901 2033-07-27         61.7              64.0              47.4
# 3902 2033-07-28         60.5              61.0              45.3
# 3903 2033-07-28         60.5              61.0              45.3
#
#       Average_barometer  Average_windspeed  Average_gustspeed  \
# 1                  29.7               26.4               36.8
# 2                  29.5               12.8               18.0
# 3                  29.7                8.3               12.2
# 4                  30.4                2.9                4.5
# 5                  29.9               16.7               23.1
# ...                 ...                ...                ...
# 3899               29.7                2.5                4.0
# 3900               29.8                1.7                2.9
# 3901               29.9                2.2                4.0
# 3902               29.7                4.0                6.2
# 3903               29.7                4.0                6.2
#
#       Average_direction  Rainfall_for_month  Rainfall_for_year  ...  \
# 1                 274.0                0.00               0.00  ...
# 2                 240.0                0.00               0.00  ...
# 3                 290.0                0.00               0.00  ...
# 4                  47.0                0.00               0.00  ...
# 5                 265.0                0.00               0.00  ...
# ...                 ...                 ...                ...  ...
# 3899              242.0                0.33               4.47  ...
# 3900              357.0                0.33               4.47  ...
# 3901               66.0                0.33               4.47  ...
# 3902              248.0                0.35               4.49  ...
# 3903              248.0                0.35               4.49  ...
#
#       Maximum_humidity  Minimum_humidity  Maximum_pressure  Minimum_pressure  \
# 1                  4.0              27.0            29.762            29.596
# 2                  4.0              16.0            29.669            29.268
# 3                  8.0              35.0            30.232            29.260
# 4                  7.0              35.0            30.566            30.227
# 5                  5.0              13.0            30.233            29.568
# ...                ...               ...               ...               ...
# 3899              90.0              36.0            29.781            29.645
# 3900              90.0              40.0            29.930            29.745
# 3901              96.0              35.0            29.941            29.781
# 3902              94.0              35.0            29.792            29.675
# 3903              94.0              35.0            29.792            29.675
#
#       Maximum_windspeed  Maximum_gust_speed  Maximum_heat_index  Month  \
# 1                  41.4                59.0                40.0      1
# 2                  35.7                51.0                52.0      1
# 3                  25.3                38.0                41.0      1
# 4                  12.7                20.0                32.0      1
# 5                  38.0                53.0                32.0      1
# ...                 ...                 ...                 ...    ...
# 3899                8.1                17.3                77.5      7
# 3900               11.5                15.0                77.5      7
# 3901               13.8                18.4                78.2      7
# 3902               17.3                26.5                77.6      7
# 3903               17.3                26.5                77.6      7
#
#       diff_pressure  year_offset
# 1             0.166            0
# 2             0.401            0
# 3             0.972            0
# 4             0.339            0
# 5             0.665            0
# ...             ...          ...
# 3899          0.136           11
# 3900          0.185           11
# 3901          0.160           11
# 3902          0.117           11
# 3903          0.117           11
#
# [3901 rows x 23 columns]

# %% [markdown]
# # Dropping Duplicate Column

# %%
df.drop('year_offset', axis=1, inplace =True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3901 entries, 1 to 3903
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     3901 non-null   datetime64[ns]
#  1   Temperature              3901 non-null   float64
#  2   Average_humidity         3901 non-null   float64
#  3   Average_dewpoint         3901 non-null   float64
#  4   Average_barometer        3901 non-null   float64
#  5   Average_windspeed        3901 non-null   float64
#  6   Average_gustspeed        3901 non-null   float64
#  7   Average_direction        3901 non-null   float64
#  8   Rainfall_for_month       3901 non-null   float64
#  9   Rainfall_for_year        3901 non-null   float64
#  10  Maximum_rain_per_minute  3901 non-null   float64
#  11  Maximum_temperature      3901 non-null   float64
#  12  Minimum_temperature      3901 non-null   float64
#  13  Maximum_humidity         3901 non-null   float64
#  14  Minimum_humidity         3901 non-null   float64
#  15  Maximum_pressure         3901 non-null   float64
#  16  Minimum_pressure         3901 non-null   float64
#  17  Maximum_windspeed        3901 non-null   float64
#  18  Maximum_gust_speed       3901 non-null   float64
#  19  Maximum_heat_index       3901 non-null   float64
#  20  Month                    3901 non-null   int32
#  21  diff_pressure            3901 non-null   float64
# dtypes: datetime64[ns](1), float64(20), int32(1)
# memory usage: 685.7 KB

# %% [markdown]
# # Exporting Cleaned File as CSV

# %%
df.to_csv(r'C:\Users\Taniya\Downloads\clean_dataset.csv', index=False)
